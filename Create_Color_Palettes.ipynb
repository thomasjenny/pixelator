# %% [markdown]
# # RGB Codes for the Color Palettes

# %%
import os
import json

# %%
# Define color palettes
sweetie_16 = [
    [26, 28, 44],
    [93, 39, 93],
    [177, 62, 83],
    [239, 125, 87],
    [255, 205, 117],
    [167, 240, 112],
    [56, 183, 100],
    [37, 113, 121],
    [41, 54, 111],
    [59, 93, 201],
    [65, 166, 246],
    [115, 239, 247],
    [244, 244, 244],
    [148, 176, 194],
    [86, 108, 134],
    [51, 60, 87]
]
better16 = [
    [0, 0, 0],
    [24, 24, 128],
    [80, 40, 16],
    [64, 64, 64],
    [24, 88, 16],
    [176, 16, 16],
    [88, 88, 232],
    [184, 56, 192],
    [128, 128, 128],
    [48, 168, 40],
    [240, 128, 0],
    [136, 176, 248],
    [56, 208, 192],
    [232, 200, 168],
    [248, 232, 64],
    [255, 255, 255]
]
pico_8 = [
    [0, 0, 0],
    [29, 43, 83],
    [126, 37, 83],
    [0, 135, 81],
    [171, 82, 54],
    [95, 87, 79],
    [194, 195, 199],
    [255, 241, 232],
    [255, 0, 77],
    [255, 163, 0],
    [255, 236, 39],
    [0, 228, 54],
    [41, 173, 255],
    [131, 118, 156],
    [255, 119, 168],
    [255, 204, 170]
]
aap_64 = [
    [6, 6, 8],
    [20, 16, 19],
    [59, 23, 37],
    [115, 23, 45],
    [180, 32, 42],
    [223, 62, 35],
    [250, 106, 10],
    [249, 163, 27],
    [255, 213, 65],
    [255, 252, 64],
    [214, 242, 100],
    [156, 219, 67],
    [89, 193, 53],
    [20, 160, 46],
    [26, 122, 62],
    [36, 82, 59],
    [18, 32, 32],
    [20, 52, 100],
    [40, 92, 196],
    [36, 159, 222],
    [32, 214, 199],
    [166, 252, 219],
    [255, 255, 255],
    [254, 243, 192],
    [250, 214, 184],
    [245, 160, 151],
    [232, 106, 115],
    [188, 74, 155],
    [121, 58, 128],
    [64, 51, 83],
    [36, 34, 52],
    [34, 28, 26],
    [50, 43, 40],
    [113, 65, 59],
    [187, 117, 71],
    [219, 164, 99],
    [244, 210, 156],
    [218, 224, 234],
    [179, 185, 209],
    [139, 147, 175],
    [109, 117, 141],
    [74, 84, 98],
    [51, 57, 65],
    [66, 36, 51],
    [91, 49, 56],
    [142, 82, 82],
    [186, 117, 106],
    [233, 181, 163],
    [227, 230, 255],
    [185, 191, 251],
    [132, 155, 228],
    [88, 141, 190],
    [71, 125, 133],
    [35, 103, 78],
    [50, 132, 100],
    [93, 175, 141],
    [146, 220, 186],
    [205, 247, 226],
    [228, 210, 170],
    [199, 176, 139],
    [160, 134, 98],
    [121, 103, 85],
    [90, 78, 68],
    [66, 57, 52]
]

# %%
# Add palettes to a dictionary
palettes = {}
palettes["sweetie_16"] = sweetie_16
palettes["better16"] = better16
palettes["pico_8"] = pico_8
palettes["aap_64"] = aap_64

# Write palettes dictionary to JSON file
path = "./palettes"
filename = "palettes.json"

with open(os.path.join(path, filename), "w") as file:
    json.dump(palettes, file)

# %%
# Test: load JSON file
with open(os.path.join(path, filename), "r") as file:
    palettes = json.load(file)

print(palettes["pico_8"])
# Out:
# [[0, 0, 0], [29, 43, 83], [126, 37, 83], [0, 135, 81], [171, 82, 54], [95, 87, 79], [194, 195, 199], [255, 241, 232], [255, 0, 77], [255, 163, 0], [255, 236, 39], [0, 228, 54], [41, 173, 255], [131, 118, 156], [255, 119, 168], [255, 204, 170]]

# %% [markdown]
# **Color palette credits**
#
# * [Sweetie 16 Palette](https://lospec.com/palette-list/sweetie-16) by GrafxKid
# * [BETTER16 Palette](https://lospec.com/palette-list/better16) by [PG](https://lospec.com/pg)
# * [PICO-8 Palette](https://lospec.com/palette-list/pico-8) by [PICO-8](https://www.lexaloffle.com/pico-8.php)
# * [AAP-64 Palette](https://lospec.com/palette-list/aap-64) by [Adigun A. Polack](https://lospec.com/adigunpolack)
